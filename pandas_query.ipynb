# %% [markdown]
# ## Como usar o query do pandas?
#
# *Aprenda a utilizar o método query do pandas para fazer consulta nos datasets.*
#
# Fala galera, tudo certo?
#
# Hoje decidi escrever sobre este método de consulta, ele aparece de forma constante em meus estudos e me despertou grande curiosidade para ir atrás e estudar mais sobre.
#
# ### Antes de tudo:
#
# Para acompanhar o passo a passo, disponibilizo todos os arquivos que você precisa:
#
# Este é o dataset que será utilizado: [Avocado Prices](https://www.kaggle.com/neuromusic/avocado-prices)
#
# E o código do tutorial você [encontra aqui!](https://github.com/matheusbattisti/pandas_query)
#
# ### loc e i loc:
#
# Além do *query*, temos também estas duas formas excelentes para nos auxiliar na busca de dados no dataset.
#
# A diferença do *query* para estes é que podemos utilizar uma expressão para encontrar o que buscamos, muito semelhante as queries de SQL.
#
# Já o loc é primariamente label based, escolhemos as colunas pelo seu nome (label) e fazemos a busca com uma condição, e o iloc é index based, com este escolhemos as porções do dataset de acordo com a posição dos índices e uma condição.
#
# Escrevi um post dedicado apenas a *loc e iloc*, se despertou sua curiosidade [confere aqui!](https://medium.com/matheusbudkewicz/data-science-tips-02-como-usar-loc-e-iloc-no-pandas-fab58e214d87)
#
# No fim das contas loc e iloc são mais utilizados, principalmente loc. Porém acredito que query tem seus méritos, a consulta parece muito mais legível, facilita para que pessoas mais leigas entendam o que está acontecendo.
#
# ### Funcionamento do query:
#
# Por baixo dos panos os resultados do *query* são passados para um DataFrame.loc e então é nos retornado o resultado, basicamente o retorno de *query* é do mesmo tipo do que o de *loc*.
#
# Além disso o metodo *pandas.eval()* é utilizado no processo também, para avaliar a query solicitada.
#
# Para mais detalhes, veja a [documentação.](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.query.html)
#
# ### Sintaxe do query:
#
# Vamos entender como podemos utilizar o método:

# %%
# Importando as libs necessárias para o post
import pandas as pd
from numpy.random import randn

# Criando um dataset genérico
df = pd.DataFrame(randn(10, 2), columns=list('ab'))

# Executando a query
df.query('a >  b')
# Out:
#           a         b
# 3  1.719751 -0.491096
# 5  0.153516 -1.522723
# 6  1.132414 -1.086465
# 7  0.821656  0.074848
# 8  0.179051 -0.346346

# %% [markdown]
# #### df:
#
# Aqui utilizamos nosso conjunto de dados, o que vamos aplicar a *query*.
#
# #### query():
#
# Chamamos o metodo *query()* no nosso conjunto de dados.
#
# #### 'a > b':
#
# Esta é a nossa expressão, no caso estamos solicitando todos os dados em que a é maior que b.
#
# #### inplace:
#
# Após a expressão o método *query*, aceita o método inplace para aplicar as modificações que fizermos no dataset, mas por default este é False.
#
# ### Avançando com query:
#
# Agora que vimos como executar a função e a explicação da sintaxe, vamos nos aprofundar mais em outras formas de utilizá-lo.
#
# Primeiro vamos ler o dataset:

# %%
# Importando o dataset de exemplos
df = pd.read_csv('avocado.csv', index_col = 0)

# Removendo espaços em branco das colunas
cols = df.columns
cols = cols.map(lambda x: x.replace(' ', '_') if isinstance(x, (str)) else x)
df.columns = cols

# Verificando dataset
df.head()
# Out:
#          Date  AveragePrice  Total_Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total_Bags  Small_Bags  Large_Bags  XLarge_Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# ### Uma condição
#
# Como vimos no primeiro exemplo, esta é consulta mais básica que *query* pode fazer, solicitamos dados a partir de uma condição, veja no exemplo:

# %%
# Solicitando os dados em que o AveragePrice é menor ou igual a 1
df.query('AveragePrice <= 1')
# Out:
#           Date  AveragePrice  Total Volume       4046       4225      4770  \
# 2   2015-12-13          0.93     118220.22     794.70  109149.67    130.50
# 6   2015-11-15          0.99      83453.76    1368.92   73672.72     93.26
# 7   2015-11-08          0.98     109428.33     703.75  101815.36     80.00
# 13  2015-09-27          0.99     106803.39    1204.88   99409.21    154.84
# 43  2015-03-01          0.99      55595.74     629.46   45633.34    181.49
# 46  2015-02-08          0.99      51253.97    1357.37   39111.81    163.25
# 47  2015-02-01          0.99      70873.60    1353.90   60017.20    179.32
# 0   2015-12-27          0.99     386100.49  292097.36   27350.92    297.90
# 2   2015-12-13          0.96     417772.47  324932.28   31019.08    275.80
# 4   2015-11-29          0.99     333280.79  250288.65   28889.63    307.83
# 5   2015-11-22          1.00     356414.57  269799.03   29732.30    501.16
# ...

# %%
# Verificando dados não são 'conventional'
df.query('type != "conventional"')
# Out:
#           Date  AveragePrice  Total_Volume       4046       4225     4770  \
# 0   2015-12-27          1.83        989.55       8.16      88.59     0.00
# 1   2015-12-20          1.89       1163.03      30.24     172.14     0.00
# 2   2015-12-13          1.85        995.96      10.44     178.70     0.00
# 3   2015-12-06          1.84       1158.42      90.29     104.18     0.00
# 4   2015-11-29          1.94        831.69       0.00      94.73     0.00
# 5   2015-11-22          1.94        858.83      13.84      84.18     0.00
# 6   2015-11-15          1.89       1208.54      20.71     238.16     0.00
# 7   2015-11-08          1.88       1332.27      20.08     351.40     0.00
# 8   2015-11-01          1.88       1021.68      11.47     137.58     0.00
# 9   2015-10-25          1.83       1161.90      49.27     148.96     0.00
# 10  2015-10-18          1.97        969.29      10.31     158.07     0.00
# 11  2015-10-11          1.90       1170.01      28.65      88.25     0.00
# ...

# %% [markdown]
# ### Duas condições
#
# Aqui o diferencial é que podemos adicionar o operador &, que vai nos proporcionar adicionar mais uma condição, tornando nossa consulta mais específica, confira:

# %%
# Vamos verificar dados com AveragePrice maior que 1 e Total_Volume < 100000
df.query('AveragePrice > 1 & Total_Volume < 100000')
# Out:
#           Date  AveragePrice  Total_Volume     4046      4225     4770  \
# 0   2015-12-27          1.33      64236.62  1036.74  54454.85    48.16
# 1   2015-12-20          1.35      54876.98   674.28  44638.81    58.33
# 3   2015-12-06          1.08      78992.15  1132.00  71976.41    72.58
# 4   2015-11-29          1.28      51039.60   941.48  43838.39    75.78
# 5   2015-11-22          1.26      55979.78  1184.27  48067.99    43.61
# 8   2015-11-01          1.02      99811.42  1022.15  87315.57    85.34
# 9   2015-10-25          1.07      74338.76   842.40  64757.44   113.00
# 10  2015-10-18          1.12      84843.44   924.86  75595.85   117.07
# 11  2015-10-11          1.28      64489.17  1582.03  52677.92   105.32
# 12  2015-10-04          1.31      61007.10  2268.32  49880.67   101.36
# 14  2015-09-20          1.33      69759.01  1028.03  59313.12   150.50
# 15  2015-09-13          1.28      76111.27   985.73  65696.86   142.00
# ...

# %%
# Verificando dados que não são da Albania e são de 2016
df.query('region != "Albany" & year == 2016')
# Out:
#           Date  AveragePrice  Total_Volume       4046       4225      4770  \
# 0   2016-12-25          0.91     502787.29  205855.78   86015.43    184.62
# 1   2016-12-18          0.94     463483.07  191753.03   80565.05    283.15
# 2   2016-12-11          1.06     422026.71  186343.72   56200.04    171.64
# 3   2016-12-04          1.03     475815.02  210602.15   93414.72    207.15
# 4   2016-11-27          1.22     372144.31  161631.62   55595.26    167.47
# 5   2016-11-20          1.14     448936.04  189206.59   58005.57    167.63
# 6   2016-11-13          1.25     408260.87  185966.29   63348.63    180.57
# 7   2016-11-06          1.29     393826.35  167083.47   65207.61    168.26
# 8   2016-10-30          1.26     408314.87  162367.80   69366.17    160.28
# 9   2016-10-23          1.23     422281.05  171215.14   67824.33    166.14
# 10  2016-10-16          1.16     459564.78  188793.29   82089.21    103.96
# ...

# %%
# Verificando Average Price maior que 1.50 ou Large_Bags maior que 200000
df.query('AveragePrice == 1 | Large_Bags > 200000')
# Out:
#           Date  AveragePrice  Total_Volume        4046        4225       4770  \
# 5   2015-11-22          1.00     356414.57   269799.03    29732.30     501.16
# 34  2015-05-03          1.00     634213.10   538403.48    28568.26    1059.73
# 40  2015-03-22          1.00     479590.62   393591.03    23419.60     304.89
# 51  2015-01-04          1.00     435021.49   364302.39    23821.16      82.15
# 34  2015-05-03          1.00      85466.99    66880.12     7942.34    4289.72
# 41  2015-03-15          1.00      65918.28    51472.29     7018.29    2981.80
# 5   2015-11-22          1.00     133618.33    30028.69    53644.97   24221.58
# 34  2015-05-03          1.00     261492.20    50203.31    69446.61   77627.49
# 8   2015-11-01          1.00     807041.46    69420.04   562214.56  106536.92
# 14  2015-09-20          1.00     165068.86    86031.90    31599.19   26200.37
# 20  2015-08-09          1.00     167387.90    64121.12    52440.39   20857.42
# ...

# %% [markdown]
# ### Usando In
#
# Podemos também verificar também por resultados especifícos, usando o in, veja:

# %%
# Consultando dados apenas dos anos 2015 e 2017
df.query('year in [2015,2017]')
# Out:
#           Date  AveragePrice  Total_Volume     4046       4225     4770  \
# 0   2015-12-27          1.33      64236.62  1036.74   54454.85    48.16
# 1   2015-12-20          1.35      54876.98   674.28   44638.81    58.33
# 2   2015-12-13          0.93     118220.22   794.70  109149.67   130.50
# 3   2015-12-06          1.08      78992.15  1132.00   71976.41    72.58
# 4   2015-11-29          1.28      51039.60   941.48   43838.39    75.78
# 5   2015-11-22          1.26      55979.78  1184.27   48067.99    43.61
# 6   2015-11-15          0.99      83453.76  1368.92   73672.72    93.26
# 7   2015-11-08          0.98     109428.33   703.75  101815.36    80.00
# 8   2015-11-01          1.02      99811.42  1022.15   87315.57    85.34
# 9   2015-10-25          1.07      74338.76   842.40   64757.44   113.00
# 10  2015-10-18          1.12      84843.44   924.86   75595.85   117.07
# 11  2015-10-11          1.28      64489.17  1582.03   52677.92   105.32
# ...

# %% [markdown]
# ## Conclusão:
#
# Vimos toda a sintaxe passo a passo do método e também como executar o mesmo em diversas situações.
#
# Perceba que podemos utilizar os operadores lógicos, como:
#
# - AND (&);
# - OR (|);
# - FALSE (!);
#
# Com este auxílio é possível formar as mais diversificadas queries, vimos também que é possível verificar elementos dentro de um array com o IN, conseguindo assim resultados mais específicos.
#
# Recomedo fortemente que você também aprenda a usar loc e iloc, pois como o *query* é mais confortável e mais *readable*, podemos nos acostumar com ele e depois nos depararmos com estes outros dois no dia a dia do trabalho, e isso pode ser um pequeno problema.
#
# Por hoje é isso pessoal, obrigado por lerem até o fim! :)
#
#
# #### Tópicos que você pode gostar:
#
# - [Iniciando na lib pandas](https://medium.com/matheusbudkewicz/o-que-%C3%A9-pandas-dando-os-primeiros-passos-na-lib-589420d075e9)
# - [Iniciando com NumPy](https://medium.com/matheusbudkewicz/iniciando-no-numpy-como-utilizar-e-m%C3%A9todos-importantes-da-lib-d00f88599c40)
# - [loc e iloc](https://medium.com/matheusbudkewicz/data-science-tips-02-como-usar-loc-e-iloc-no-pandas-fab58e214d87)
